# %%
#!/usr/bin/env python
# coding: utf-8
import os
from os import system
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

from tm.core.prior import GlobalEquilibriumHarmonicPrior, UnitNormalPrior
from tm.core.backbone import ConvBackbone
from tm.core.diffusion_model import DiffusionTrainer, SteeredDiffusionSampler
from tm.core.diffusion_process import VPDiffusion
from tm.architectures.unet_2d_mid_attn import Unet2D
#from tm.architectures.UNet2D_pbc import Unet2D
from tm.core.loader import Loader
import seaborn as sns

import os
if not os.path.exists('plots/'):
    os.mkdir('plots')

# %%
highP= np.load('data/lambda13_af_p8.npy')
lowP = np.load('data/lambda13_af_p1.npy')

lowP  = lowP.reshape(lowP.shape[0],lowP.shape[1],16,16)
highP  = highP.reshape(highP.shape[0],highP.shape[1],16,16)

p_data_coordinate = np.concatenate((lowP, highP, ), axis=0)
p_data_coordinate.shape
# Out:
# (20000, 2, 16, 16)

# %%
# Transpose data to shape (10000, channel, 15, 15)
# p_data_coordinate = p_data_coordinate.transpose(0, 3, 1, 2)
# p_data_coordinate.shape


# Initialize pressure values
pressure = np.array([-2, 2])
pressure_list = np.ones(p_data_coordinate.shape[0]*2)
temperature_list = 2* np.ones(p_data_coordinate.shape[0]*2)

for i in range(2):
    pressure_list[p_data_coordinate.shape[0]*i:p_data_coordinate.shape[0]*(i+1)] = pressure[i]

# Add two additional channels for temperature and pressure
expanded_data = np.zeros((p_data_coordinate.shape[0],4, p_data_coordinate.shape[2], p_data_coordinate.shape[3]))

# Copy original data to the expanded array
expanded_data[:, :2, :, :] = p_data_coordinate
# print(expanded_data.shape)

# Set the 4th channel to 400 (temperature)
expanded_data[:, 2, :, :] = 2

# # Set the 5th channel to the pressure values
# expanded_data[:, 13, :, :] = p_data_coordinate[:, 12, :, :]

data_sh = int(expanded_data.shape[0]/2)

expanded_data[:data_sh,3,:,:] = pressure[0]
expanded_data[data_sh:,3,:,:] = pressure[1]

# Create trajectory dictionary
trajectoryP = {'coordinate': [], 'state_variables': [],'state_variables_P': []}
trajectoryP['coordinate'] = expanded_data[:, :4, :, :]
trajectoryP['state_variables_P'] = pressure_list
trajectoryP['state_variables'] = temperature_list

# %%
train_loader = Loader(data=trajectoryP['coordinate'], pressures =trajectoryP['state_variables_P'][:,None] , temperatures=trajectoryP['state_variables'][:,None],control_dims=(12,14))#, **TMLoader_kwargs)
prior = GlobalEquilibriumHarmonicPrior(shape=train_loader.data.shape, channels_info={"coordinate": [0,1], "fluctuation": [2], "mean": [3]})
model = Unet2D(dim=16, dim_mults=(1, 2, 4), resnet_block_groups=8, channels=4)

# %%
backbone = ConvBackbone(model=model,
                        data_shape=train_loader.data_dim,
                        target_shape=16,
                        num_dims=4,
                        lr=1e-3,
                        eval_mode="train",
                        self_condition=True)

diffusion = VPDiffusion(num_diffusion_timesteps=100)

if not os.path.exists('models'):
    os.mkdir('models')


trainer = DiffusionTrainer(diffusion,
                           backbone,
                           train_loader,
                           prior,
                           model_dir="thermomaps-root/models", # save models every epoch
                           pred_type="x0", # set to "noise" or "x0"
#                            test_loader=test_loader # optional
                           )

trainer.train(50, loss_type="smooth_l1", batch_size=128)
# Out:
# epoch: 0 | train loss: 0.043
# epoch: 1 | train loss: 0.010
# epoch: 2 | train loss: 0.009
# epoch: 3 | train loss: 0.009
# epoch: 4 | train loss: 0.009
# epoch: 5 | train loss: 0.008
# epoch: 6 | train loss: 0.008
# epoch: 7 | train loss: 0.008
# epoch: 8 | train loss: 0.008
# epoch: 9 | train loss: 0.007
# epoch: 10 | train loss: 0.008
# epoch: 11 | train loss: 0.007
# epoch: 12 | train loss: 0.007
# epoch: 13 | train loss: 0.008
# epoch: 14 | train loss: 0.006
# epoch: 15 | train loss: 0.008
# epoch: 16 | train loss: 0.007
# epoch: 17 | train loss: 0.007
# epoch: 18 | train loss: 0.006
# epoch: 19 | train loss: 0.007
# epoch: 20 | train loss: 0.007
# epoch: 21 | train loss: 0.006
# epoch: 22 | train loss: 0.006
# epoch: 23 | train loss: 0.006
# epoch: 24 | train loss: 0.007
# epoch: 25 | train loss: 0.006
# epoch: 26 | train loss: 0.006
# epoch: 27 | train loss: 0.006
# epoch: 28 | train loss: 0.007
# epoch: 29 | train loss: 0.007
# epoch: 30 | train loss: 0.007
# epoch: 31 | train loss: 0.006
# epoch: 32 | train loss: 0.006
# epoch: 33 | train loss: 0.006
# epoch: 34 | train loss: 0.007
# epoch: 35 | train loss: 0.007
# epoch: 36 | train loss: 0.006
# epoch: 37 | train loss: 0.006
# epoch: 38 | train loss: 0.007
# epoch: 39 | train loss: 0.006
# epoch: 40 | train loss: 0.006
# epoch: 41 | train loss: 0.006
# epoch: 42 | train loss: 0.006
# epoch: 43 | train loss: 0.007
# epoch: 44 | train loss: 0.006
# epoch: 45 | train loss: 0.007
# epoch: 46 | train loss: 0.006
# epoch: 47 | train loss: 0.006
# epoch: 48 | train loss: 0.005
# epoch: 49 | train loss: 0.007

# %%
# *********************************************************************************
#                               Sampling
# *********************************************************************************
sampler = SteeredDiffusionSampler(diffusion,
                                  backbone,
                                  train_loader,
                                  prior,
                                  pred_type='x0', # must be the same as in DiffusionTrainer
                                  )


num_samp = 1000

high_samples = sampler.sample_loop(num_samples=num_samp, batch_size=32, pressure=2 , temperature=1)
low_samples = sampler.sample_loop(num_samples=num_samp, batch_size=32, pressure=-2, temperature=1)
high_samples = high_samples.numpy()
low_samples = low_samples.numpy()

# %%
# high_samples = high_samples.numpy()
# low_samples = low_samples.numpy()

# %%
high_samples.shape
# Out:
# (992, 4, 16, 16)

# %%
mid_samples = sampler.sample_loop(num_samples=num_samp, batch_size=32, pressure=0 , temperature=1)
mid_samples = mid_samples.numpy()

# %%
high_gen_data = high_samples[:,:2,:,:].reshape(high_samples.shape[0],2,256)
low_gen_data = low_samples[:,:2,:,:].reshape(low_samples.shape[0],2,256)
mid_gen_data = mid_samples[:,:2,:,:].reshape(mid_samples.shape[0],2,256)

# %%
highP_ref= np.load('data/lambda13_af_p8.npy')
lowP_ref = np.load('data/lambda13_af_p1.npy')

# %%
plt.figure(figsize=(5,4.5))

# p=1 (ref) and (gen) share the same color
plt.scatter(lowP_ref[:,0,:].mean(axis=1), lowP_ref[:,1,:].mean(axis=1), 
            label='(ref) p=1', alpha=0.9, color='red')
plt.scatter(low_gen_data[:,0,:].mean(axis=1), low_gen_data[:,1,:].mean(axis=1), 
            label='(gen)* p=1', color='orangered')

# p=8 (ref) and (gen) share the same color
plt.scatter(highP_ref[:,0,:].mean(axis=1), highP_ref[:,1,:].mean(axis=1), 
            label='(ref) p=8', alpha=0.9, color='blue')
plt.scatter(high_gen_data[:,0,:].mean(axis=1), high_gen_data[:,1,:].mean(axis=1), 
            label='(gen)* p=8', color='dodgerblue')

plt.scatter(mid_gen_data[:,0,:].mean(axis=1), mid_gen_data[:,1,:].mean(axis=1), 
            label='(gen)* p=4.5', color='limegreen')

plt.xlabel(r'$\lambda_1$',fontsize= 15)
plt.ylabel(r'$\lambda_3$',fontsize= 15)
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

plt.figure(figsize=(5, 4.5))
pressure_range = [-2,-1.5, -1, -0.5,0,0.5, 1,1.5, 2]
pressure_actual = np.linspace(1,9,len(pressure_range))#[1, 2.75, 4.5, 7.25, 9]
num_samp1 = 1000

# Define a color map (e.g., 'Blues' for blue gradient)
color_map = cm.get_cmap('coolwarm', len(pressure_range))
gen_samples_pressure= [] 
for i, p in enumerate(pressure_range):
    gen_samples = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=p, temperature=1.5)
    gen_samples = gen_samples.numpy()
    gen_samples = gen_samples[:, :2, :, :].reshape(gen_samples.shape[0], 2, 256)
    gen_samples_pressure.append(gen_samples)
    # Set color based on pressure index
    color = color_map(i / len(pressure_range))
    plt.scatter(gen_samples[:, 0, :].mean(axis=1), gen_samples[:, 1, :].mean(axis=1),
                label=f'(gen) p={pressure_actual[i]:.2f}', alpha=0.6, color=color)

plt.legend()
plt.xlabel(r'$\lambda_1$', fontsize=15)
plt.ylabel(r'$\lambda_3$', fontsize=15)
plt.show()
# Out:
# /tmp/ipykernel_574572/663801141.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = cm.get_cmap('coolwarm', len(pressure_range))

# %%
gen_samples_pressure = np.array(gen_samples_pressure)

# %%
np.save('gen_samples_pressure.npy',gen_samples_pressure)

# %%
import matplotlib.cm as cm

# Define temperature ranges
temperature_range = [1, 2.5, 5]
temperature_actual = np.linspace(1,5,3)#[#1, 2.5, 5]
num_samp1 = 1000

# Define color maps for blue and orange gradients, starting from a slightly darker level
blue_cmap = cm.coolwarm(np.linspace(0, .45, 256))  # Start at 0.3 for darker blue shades
orange_cmap = cm.coolwarm(np.linspace(0.55, .2, 256))  # Start at 0.3 for darker orange shades
green_cmap = cm.coolwarm(np.linspace(0.45,.55, 256))  # Start at 0.3 for darker orange shades

# Normalize temperature for color mapping
norm = plt.Normalize(min(temperature_range), max(temperature_range))

gen_samples_lam1_temp = []
gen_samples_lam2_temp = []
gen_samples_lam3_temp = []

plt.figure(figsize=(5,4.5))
for i, t in enumerate(temperature_range):
    gen_samples_lam1 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=-1.5, temperature=t)
    gen_samples_lam1 = gen_samples_lam1.numpy()[:, :2, :, :].reshape(gen_samples_lam1.shape[0], 2, 256)
    color_orange = orange_cmap[int(norm(t) * 255)]
    gen_samples_lam1_temp.append(gen_samples_lam1)
    # Plot gen_samples_lam1 with the orange gradient for p=1
    plt.scatter(gen_samples_lam1[:, 0, :].mean(axis=1), gen_samples_lam1[:, 1, :].mean(axis=1), 
                label=f'(gen) p=1, t={temperature_actual[i]:.1f} K', color=color_orange)

plt.legend()

for i, t in enumerate(temperature_range):
    # Sampling
    gen_samples_lam3 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=1.5, temperature=t)
    gen_samples_lam3 = gen_samples_lam3.numpy()[:, :2, :, :].reshape(gen_samples_lam3.shape[0], 2, 256)
    color_blue = blue_cmap[int(norm(t) * 255)]
    gen_samples_lam3_temp.append(gen_samples_lam3)
    # Plot gen_samples_lam3 with the blue gradient for p=8
    plt.scatter(gen_samples_lam3[:, 0, :].mean(axis=1), gen_samples_lam3[:, 1, :].mean(axis=1), 
                label=f'(gen) p=8, t={temperature_actual[i]:.1f} K', color=color_blue)

for i, t in enumerate(temperature_range):
    # Sampling
    gen_samples_lam2 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=0, temperature=t)
    gen_samples_lam2 = gen_samples_lam2.numpy()[:, :2, :, :].reshape(gen_samples_lam2.shape[0], 2, 256)
    color_green = green_cmap[int(norm(t) * 255)]
    gen_samples_lam2_temp.append(gen_samples_lam2)
    # Plot gen_samples_lam3 with the blue gradient for p=8
    plt.scatter(gen_samples_lam2[:, 0, :].mean(axis=1), gen_samples_lam2[:, 1, :].mean(axis=1), 
                label=f'(gen) p=4.5, t={temperature_actual[i]:.1f} K', color=color_green)

# Final plot adjustments
plt.xlabel(r'$\lambda_1$', fontsize=15)
plt.ylabel(r'$\lambda_3$', fontsize=15)
plt.legend()

gen_samples_lam1_temp = np.array(gen_samples_lam1_temp)
gen_samples_lam2_temp = np.array(gen_samples_lam2_temp)
gen_samples_lam3_temp = np.array(gen_samples_lam3_temp)

np.save('gen_samples_lam1_temp.npy',gen_samples_lam1_temp)
np.save('gen_samples_lam2_temp.npy',gen_samples_lam2_temp)
np.save('gen_samples_lam3_temp.npy',gen_samples_lam3_temp)

# %%
plt.figure(figsize=(5,4.5))
# plt.scatter(lowP_ref[:,0,:].mean(axis=1), lowP_ref[:,1,:].mean(axis=1), 
#             label='(ref) p=1', alpha=0.3, color='red')
plt.scatter(low_gen_data[:,0,:].mean(axis=1), low_gen_data[:,1,:].mean(axis=1), 
            label='(gen) p=1', color='red')

plt.scatter(mid_gen_data[:,0,:].mean(axis=1), mid_gen_data[:,1,:].mean(axis=1), 
            label='(gen) p=5', color='green')

# p=8 (ref) and (gen) share the same color
# plt.scatter(highP_ref[:,0,:].mean(axis=1), highP_ref[:,1,:].mean(axis=1), 
#             label='(ref) p=8', alpha=0.3, color='blue')
plt.scatter(high_gen_data[:,0,:].mean(axis=1), high_gen_data[:,1,:].mean(axis=1), 
            label='(gen) p=8', color='b')

plt.xlabel(r'$\lambda_1$',fontsize= 15)
plt.ylabel(r'$\lambda_3$',fontsize= 15)
plt.legend()

# %%
# plt.figure(figsize=(5,4.5))
# pressure_range =[-2,-1,0,1,2]
# pressure_actual = [1,2.75,4.5,7.25,9]
# num_samp1=250
# for i,p in enumerate(pressure_range):
#     gen_samples = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=p , temperature=1)
#     gen_samples = gen_samples.numpy()
#     gen_samples = gen_samples[:,:2,:,:].reshape(gen_samples.shape[0],2,256)
#     plt.scatter(gen_samples[:,0,:].mean(axis=1), gen_samples[:,1,:].mean(axis=1), label='(gen) p=%2.2f'%(pressure_actual[i]),alpha=0.6)#, color='green')
#     plt.legend()
# plt.xlabel(r'$\lambda_1$',fontsize= 15)
# plt.ylabel(r'$\lambda_3$',fontsize= 15)

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import matplotlib.cm as cm

# plt.figure(figsize=(5, 4.5))
# pressure_range = [-2, -1, 0, 1, 2]
# pressure_actual = [1, 2.75, 4.5, 7.25, 9]
# num_samp1 = 1000

# # Define a color map (e.g., 'Blues' for blue gradient)
# color_map = cm.get_cmap('coolwarm', len(pressure_range))

# for i, p in enumerate(pressure_range):
#     gen_samples = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=p, temperature=1)
#     gen_samples = gen_samples.numpy()
#     gen_samples = gen_samples[:, :2, :, :].reshape(gen_samples.shape[0], 2, 256)
    
#     # Set color based on pressure index
#     color = color_map(i / len(pressure_range))
#     plt.scatter(gen_samples[:, 0, :].mean(axis=1), gen_samples[:, 1, :].mean(axis=1),
#                 label=f'(gen) p={pressure_actual[i]:.2f}', alpha=0.6, color=color)

# plt.legend()
# plt.xlabel(r'$\lambda_1$', fontsize=15)
# plt.ylabel(r'$\lambda_3$', fontsize=15)
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

plt.figure(figsize=(5, 4.5))
pressure_range = [-2,-1.5, -1, -0.5,0,0.5, 1,1.5, 2]
pressure_actual = np.linspace(1,9,len(pressure_range))#[1, 2.75, 4.5, 7.25, 9]
num_samp1 = 1000

# Define a color map (e.g., 'Blues' for blue gradient)
color_map = cm.get_cmap('coolwarm', len(pressure_range))

for i, p in enumerate(pressure_range):
    gen_samples = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=p, temperature=1)
    gen_samples = gen_samples.numpy()
    gen_samples = gen_samples[:, :2, :, :].reshape(gen_samples.shape[0], 2, 256)
    
    # Set color based on pressure index
    color = color_map(i / len(pressure_range))
    plt.scatter(gen_samples[:, 0, :].mean(axis=1), gen_samples[:, 1, :].mean(axis=1),
                label=f'(gen) p={pressure_actual[i]:.2f}', alpha=0.6, color=color)

plt.legend()
plt.xlabel(r'$\lambda_1$', fontsize=15)
plt.ylabel(r'$\lambda_3$', fontsize=15)
plt.show()
# Out:
# /var/tmp/ipykernel_71978/332517987.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = cm.get_cmap('coolwarm', len(pressure_range))

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

plt.figure(figsize=(5, 4.5))
pressure_range = [-2,-1.5, -1, -0.5,0,0.5, 1,1.5, 2]
pressure_actual = np.linspace(1,9,len(pressure_range))#[1, 2.75, 4.5, 7.25, 9]
num_samp1 = 1000

# Define a color map (e.g., 'Blues' for blue gradient)
color_map = cm.get_cmap('coolwarm', len(pressure_range))

for i, p in enumerate(pressure_range):
    gen_samples = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=p, temperature=1.5)
    gen_samples = gen_samples.numpy()
    gen_samples = gen_samples[:, :2, :, :].reshape(gen_samples.shape[0], 2, 256)
    
    # Set color based on pressure index
    color = color_map(i / len(pressure_range))
    plt.scatter(gen_samples[:, 0, :].mean(axis=1), gen_samples[:, 1, :].mean(axis=1),
                label=f'(gen) p={pressure_actual[i]:.2f}', alpha=0.6, color=color)

plt.legend()
plt.xlabel(r'$\lambda_1$', fontsize=15)
plt.ylabel(r'$\lambda_3$', fontsize=15)
plt.show()

# %%
import matplotlib.cm as cm

# Define temperature ranges
temperature_range = [1, 2.5, 5]
temperature_actual = [1, 2.5, 5]
num_samp1 = 500

# Define color maps for blue and orange gradients, starting from a slightly darker level
blue_cmap = cm.Blues(np.linspace(0.3, 1, 256))  # Start at 0.3 for darker blue shades
orange_cmap = cm.Oranges(np.linspace(0.3, 1, 256))  # Start at 0.3 for darker orange shades
green_cmap = cm.Greens(np.linspace(0.3,1, 256))  # Start at 0.3 for darker orange shades

# Normalize temperature for color mapping
norm = plt.Normalize(min(temperature_range), max(temperature_range))

plt.figure(figsize=(5,4.5))
for i, t in enumerate(temperature_range):
    gen_samples_lam1 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=-1.5, temperature=t)
    gen_samples_lam1 = gen_samples_lam1.numpy()[:, :2, :, :].reshape(gen_samples_lam1.shape[0], 2, 256)
    color_orange = orange_cmap[int(norm(t) * 255)]
    
    # Plot gen_samples_lam1 with the orange gradient for p=1
    plt.scatter(gen_samples_lam1[:, 0, :].mean(axis=1), gen_samples_lam1[:, 1, :].mean(axis=1), 
                label=f'(gen) p=1, t={temperature_actual[i]:.1f} K', color=color_orange)

plt.legend()

for i, t in enumerate(temperature_range):
    # Sampling
    gen_samples_lam3 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=1.5, temperature=t)
    gen_samples_lam3 = gen_samples_lam3.numpy()[:, :2, :, :].reshape(gen_samples_lam3.shape[0], 2, 256)
    color_blue = blue_cmap[int(norm(t) * 255)]
    
    # Plot gen_samples_lam3 with the blue gradient for p=8
    plt.scatter(gen_samples_lam3[:, 0, :].mean(axis=1), gen_samples_lam3[:, 1, :].mean(axis=1), 
                label=f'(gen) p=8, t={temperature_actual[i]:.1f} K', color=color_blue)

for i, t in enumerate(temperature_range):
    # Sampling
    gen_samples_lam2 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=0, temperature=t)
    gen_samples_lam2 = gen_samples_lam2.numpy()[:, :2, :, :].reshape(gen_samples_lam2.shape[0], 2, 256)
    color_green = green_cmap[int(norm(t) * 255)]
    
    # Plot gen_samples_lam3 with the blue gradient for p=8
    plt.scatter(gen_samples_lam2[:, 0, :].mean(axis=1), gen_samples_lam2[:, 1, :].mean(axis=1), 
                label=f'(gen) p=4.5, t={temperature_actual[i]:.1f} K', color=color_green)

# Final plot adjustments
plt.xlabel(r'$\lambda_1$', fontsize=15)
plt.ylabel(r'$\lambda_3$', fontsize=15)
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

plt.figure(figsize=(5, 4.5))
pressure_range = [-2,-1.5, -1, -0.5,0,0.5, 1,1.5, 2]
pressure_actual = [1, 2.75, 4.5, 7.25, 9]
num_samp1 = 1000

# Define a color map (e.g., 'Blues' for blue gradient)
color_map = cm.get_cmap('coolwarm', len(pressure_range))

for i, p in enumerate(pressure_range):
    gen_samples = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=p, temperature=1.5)
    gen_samples = gen_samples.numpy()
    gen_samples = gen_samples[:, :2, :, :].reshape(gen_samples.shape[0], 2, 256)
    
    # Set color based on pressure index
    color = color_map(i / len(pressure_range))
    plt.scatter(gen_samples[:, 0, :].mean(axis=1), gen_samples[:, 1, :].mean(axis=1),
                label=f'(gen) p={pressure_actual[i]:.2f}', alpha=0.6, color=color)

plt.legend()
plt.xlabel(r'$\lambda_1$', fontsize=15)
plt.ylabel(r'$\lambda_3$', fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm

plt.figure(figsize=(5, 4.5))
pressure_range = [-2,-1.5, -1, -0.5,0,0.5, 1,1.5, 2]
pressure_actual = [1, 2.75, 4.5, 7.25, 9]
num_samp1 = 1000

# Define a color map (e.g., 'Blues' for blue gradient)
color_map = cm.get_cmap('coolwarm', len(pressure_range))

for i, p in enumerate(pressure_range):
    gen_samples = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=p, temperature=1)
    gen_samples = gen_samples.numpy()
    gen_samples = gen_samples[:, :2, :, :].reshape(gen_samples.shape[0], 2, 256)
    
    # Set color based on pressure index
    color = color_map(i / len(pressure_range))
    plt.scatter(gen_samples[:, 0, :].mean(axis=1), gen_samples[:, 1, :].mean(axis=1),
                label=f'(gen) p={pressure_actual[i]:.2f}', alpha=0.6, color=color)

plt.legend()
plt.xlabel(r'$\lambda_1$', fontsize=15)
plt.ylabel(r'$\lambda_3$', fontsize=15)
plt.show()
# Out:
# /var/tmp/ipykernel_13859/3125772034.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = cm.get_cmap('seismic', len(pressure_range))

# %%
temperature_range =[1,2.5,5]
temperature_actual = [1,2.5,5]
num_samp1=100
for i,t in enumerate(temperature_range):
    gen_samples_lam3 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=2 , temperature=t)
    gen_samples_lam1 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=-2 , temperature=t)
    
    gen_samples_lam3 = gen_samples_lam3.numpy()
    gen_samples_lam3 = gen_samples_lam3[:,:2,:,:].reshape(gen_samples_lam3.shape[0],2,256)
    plt.scatter(gen_samples_lam3[:,0,:].mean(axis=1), gen_samples_lam3[:,1,:].mean(axis=1), label='(gen) p=8, t=%2.0f k'%(temperature_actual[i]))#, color='green')
    gen_samples_lam1 = gen_samples_lam1.numpy()
    gen_samples_lam1 = gen_samples_lam1[:,:2,:,:].reshape(gen_samples_lam1.shape[0],2,256)
    plt.scatter(gen_samples_lam1[:,0,:].mean(axis=1), gen_samples_lam1[:,1,:].mean(axis=1), label='(gen) p=1, t=%2.0f k'%(temperature_actual[i]))#, color='green')
    plt.legend()
plt.xlabel(r'$\lambda_1$',fontsize= 15)
plt.ylabel(r'$\lambda_3$',fontsize= 15)
# Out:
# Text(0, 0.5, '$\\lambda_3$')

# %%
import matplotlib.cm as cm

# Define temperature ranges
temperature_range = [1, 2.5, 5]
temperature_actual = [1, 2.5, 5]
num_samp1 = 500

# Define color maps for blue and orange gradients, starting from a slightly darker level
blue_cmap = cm.Blues(np.linspace(0.3, 1, 256))  # Start at 0.3 for darker blue shades
orange_cmap = cm.Oranges(np.linspace(0.3, 1, 256))  # Start at 0.3 for darker orange shades
green_cmap = cm.Greens(np.linspace(0.3,1, 256))  # Start at 0.3 for darker orange shades

# Normalize temperature for color mapping
norm = plt.Normalize(min(temperature_range), max(temperature_range))

plt.figure(figsize=(5,4.5))
for i, t in enumerate(temperature_range):
    gen_samples_lam1 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=-1.5, temperature=t)
    gen_samples_lam1 = gen_samples_lam1.numpy()[:, :2, :, :].reshape(gen_samples_lam1.shape[0], 2, 256)
    color_orange = orange_cmap[int(norm(t) * 255)]
    
    # Plot gen_samples_lam1 with the orange gradient for p=1
    plt.scatter(gen_samples_lam1[:, 0, :].mean(axis=1), gen_samples_lam1[:, 1, :].mean(axis=1), 
                label=f'(gen) p=1, t={temperature_actual[i]:.1f} K', color=color_orange)

plt.legend()

for i, t in enumerate(temperature_range):
    # Sampling
    gen_samples_lam3 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=1.5, temperature=t)
    gen_samples_lam3 = gen_samples_lam3.numpy()[:, :2, :, :].reshape(gen_samples_lam3.shape[0], 2, 256)
    color_blue = blue_cmap[int(norm(t) * 255)]
    
    # Plot gen_samples_lam3 with the blue gradient for p=8
    plt.scatter(gen_samples_lam3[:, 0, :].mean(axis=1), gen_samples_lam3[:, 1, :].mean(axis=1), 
                label=f'(gen) p=8, t={temperature_actual[i]:.1f} K', color=color_blue)

for i, t in enumerate(temperature_range):
    # Sampling
    gen_samples_lam2 = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=0, temperature=t)
    gen_samples_lam2 = gen_samples_lam2.numpy()[:, :2, :, :].reshape(gen_samples_lam2.shape[0], 2, 256)
    color_green = green_cmap[int(norm(t) * 255)]
    
    # Plot gen_samples_lam3 with the blue gradient for p=8
    plt.scatter(gen_samples_lam2[:, 0, :].mean(axis=1), gen_samples_lam2[:, 1, :].mean(axis=1), 
                label=f'(gen) p=4.5, t={temperature_actual[i]:.1f} K', color=color_green)

# Final plot adjustments
plt.xlabel(r'$\lambda_1$', fontsize=15)
plt.ylabel(r'$\lambda_3$', fontsize=15)
plt.legend()

# %%
temperature_range =[1,2.5,5]
temperature_actual = [1,2.5,5]
num_samp1=100
for i,t in enumerate(temperature_range):
    gen_samples = sampler.sample_loop(num_samples=num_samp1, batch_size=32, pressure=1 , temperature=t)
    gen_samples = gen_samples.numpy()
    gen_samples = gen_samples[:,:2,:,:].reshape(gen_samples.shape[0],2,256)
    plt.scatter(gen_samples[:,0,:].mean(axis=1), gen_samples[:,1,:].mean(axis=1), label='(gen) t=%2.2f k'%(temperature_actual[i]))#, color='green')
    plt.legend()
plt.xlabel(r'$\lambda_1$',fontsize= 15)
plt.ylabel(r'$\lambda_3$',fontsize= 15)

# %%
# lambda1 = low_gen_data.mean(axis=2)
# lambda3 = high_gen_data.mean(axis=2)

# highP_reference= np.load('data/lambda13_af_p8.npy')
# lowP_reference = np.load('data/lambda13_af_p1.npy')
# # print(highP_reference.shape)
# lambda1_ref = lowP_reference.mean(axis=2)
# lambda3_ref = highP_reference.mean(axis=2)

# plt.figure(figsize=(5,4.5))
# plt.scatter(lambda1_ref[:,0],lambda1_ref[:,1],)
# plt.scatter(lambda1[:,0],lambda1[:,1])

# plt.scatter(lambda3_ref[:,0],lambda3_ref[:,1])
# plt.scatter(lambda3[:,0],lambda3[:,1])

# %%
# # lambda1 = low_gen_data.mean(axis=2)
# lambda3 = high_gen_data.mean(axis=2)

# plt.figure(figsize=(5,4.5))
# plt.scatter(lambda1[:,0],lambda1[:,1])
# plt.scatter(lambda3[:,0],lambda3[:,1])

# %%
lambda1 = low_gen_data.mean(axis=2)
lambda3 = high_gen_data.mean(axis=2)

plt.figure(figsize=(5,4.5))
plt.scatter(lambda1[:,0],lambda1[:,1])
plt.scatter(lambda3[:,0],lambda3[:,1])

# %%
highP_reference= np.load('data/lambda13_af_p8.npy')
lowP_reference = np.load('data/lambda13_af_p1.npy')

lambda1_ref = lowP_reference.mean(axis=2)
lambda3_ref = highP_reference.mean(axis=2)

# %%
plt.plot(highP_reference[11,0,:])
plt.plot(highP_reference[-11,0,:])
# plt.plot(tmp1[-17,0,:])

# %%
plt.hist(lambda1_ref[:,0],color='b')
plt.hist(lambda1_ref[:,1],color='skyblue')

plt.hist(lambda1[:,0],color='r')
plt.hist(lambda1[:,1],color='orange')
# Out:
# (array([  5.,  51., 126., 215., 259., 190., 105.,  33.,   6.,   2.]),
#  array([-0.04803596, -0.04758866, -0.04714136, -0.04669405, -0.04624675,
#         -0.04579945, -0.04535214, -0.04490484, -0.04445753, -0.04401023,
#         -0.04356293]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(lambda1_ref[:,0],color='b')
plt.hist(lambda1_ref[:,1],color='skyblue')

plt.hist(lambda1[:,0],color='r')
plt.hist(lambda1[:,1],color='orange')
# Out:
# (array([  5.,  51., 126., 215., 259., 190., 105.,  33.,   6.,   2.]),
#  array([-0.04803596, -0.04758866, -0.04714136, -0.04669405, -0.04624675,
#         -0.04579945, -0.04535214, -0.04490484, -0.04445753, -0.04401023,
#         -0.04356293]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(lambda1_ref[:,0])
plt.plot(lambda1[:,0])

# plt.plot(lambda1_ref[:,1])
# plt.plot(lambda1[:,1])

# %%
plt.plot(lambda3_ref[:,0])
plt.plot(lambda3[:,0])

plt.plot(lambda3_ref[:,1])
plt.plot(lambda3[:,1])

# %%
highP_reference.shape
# Out:
# (10000, 2, 256)

# %%
# lambda3_ref

highP_ref_img = highP_reference[:10,:,:]
highP_ref_img = highP_ref_img.reshape(10,2,16,16)

# %%
plt.figure(figsize=(10,8))
for i in range(10):
    plt.subplot(2,5,i+1)
    im = plt.imshow(highP_ref_img[-i,0,:,:], vmin=0, vmax=1)
    plt.colorbar(im)

# %%
# high_samples[:,0,:,:]

plt.figure(figsize=(10,8))
for i in range(10):
    plt.subplot(2,5,i+1)
    im = plt.imshow(high_samples[i,0,:,:], vmin=0, vmax=1)
    plt.colorbar(im)
