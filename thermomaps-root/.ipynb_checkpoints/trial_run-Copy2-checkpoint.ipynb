# %%
#!/usr/bin/env python
# coding: utf-8
import os
from os import system
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

from tm.core.prior import GlobalEquilibriumHarmonicPrior, UnitNormalPrior
from tm.core.backbone import ConvBackbone
from tm.core.diffusion_model import DiffusionTrainer, SteeredDiffusionSampler
from tm.core.diffusion_process import VPDiffusion
from tm.architectures.unet_2d_mid_attn import Unet2D
#from tm.architectures.UNet2D_pbc import Unet2D
from tm.core.loader import Loader
import seaborn as sns


# Define the path to the directory you want to change to
#dirc_path = 'thermomaps-root'
#os.chdir(dirc_path)

import os
if not os.path.exists('plots/'):
    os.mkdir('plots')

# %%
highP= np.load('data/lambda13_af_p8.npy')
lowP = np.load('data/lambda13_af_p1.npy')

lowP  = lowP.reshape(lowP.shape[0],lowP.shape[1],16,16)
highP  = highP.reshape(highP.shape[0],highP.shape[1],16,16)

p_data_coordinate = np.concatenate((lowP, highP, ), axis=0)
p_data_coordinate.shape
# Out:
# (20000, 2, 16, 16)

# %%
# Transpose data to shape (10000, channel, 15, 15)
# p_data_coordinate = p_data_coordinate.transpose(0, 3, 1, 2)
# p_data_coordinate.shape


# Initialize pressure values
pressure = np.array([1, 8.0])
pressure_list = np.ones(p_data_coordinate.shape[0]*2)
temperature_list = 2* np.ones(p_data_coordinate.shape[0]*2)

for i in range(2):
    pressure_list[p_data_coordinate.shape[0]*i:p_data_coordinate.shape[0]*(i+1)] = pressure[i]

# Add two additional channels for temperature and pressure
expanded_data = np.zeros((p_data_coordinate.shape[0],4, p_data_coordinate.shape[2], p_data_coordinate.shape[3]))

# Copy original data to the expanded array
expanded_data[:, :2, :, :] = p_data_coordinate
# print(expanded_data.shape)

# Set the 4th channel to 400 (temperature)
expanded_data[:, 2, :, :] = 2

# # Set the 5th channel to the pressure values
# expanded_data[:, 13, :, :] = p_data_coordinate[:, 12, :, :]

data_sh = int(expanded_data.shape[0]/2)

expanded_data[:data_sh,3,:,:] = pressure[0]
expanded_data[data_sh:,3,:,:] = pressure[1]

# Create trajectory dictionary
trajectoryP = {'coordinate': [], 'state_variables': [],'state_variables_P': []}
trajectoryP['coordinate'] = expanded_data[:, :4, :, :]
trajectoryP['state_variables_P'] = pressure_list
trajectoryP['state_variables'] = temperature_list

# %%
train_loader = Loader(data=trajectoryP['coordinate'], pressures =trajectoryP['state_variables_P'][:,None] , temperatures=trajectoryP['state_variables'][:,None],control_dims=(12,14))#, **TMLoader_kwargs)
prior = GlobalEquilibriumHarmonicPrior(shape=train_loader.data.shape, channels_info={"coordinate": [0,1], "fluctuation": [2], "mean": [3]})
model = Unet2D(dim=16, dim_mults=(1, 2, 4), resnet_block_groups=8, channels=4)

# %%
backbone = ConvBackbone(model=model,
                        data_shape=train_loader.data_dim,
                        target_shape=16,
                        num_dims=4,
                        lr=1e-3,
                        eval_mode="train",
                        self_condition=True)

diffusion = VPDiffusion(num_diffusion_timesteps=100)

if not os.path.exists('models'):
    os.mkdir('models')


trainer = DiffusionTrainer(diffusion,
                           backbone,
                           train_loader,
                           prior,
                           model_dir="thermomaps-root/models", # save models every epoch
                           pred_type="x0", # set to "noise" or "x0"
#                            test_loader=test_loader # optional
                           )

trainer.train(250, loss_type="smooth_l1", batch_size=128)
# Out:
# epoch: 0 | train loss: 0.160
# epoch: 1 | train loss: 0.015
# epoch: 2 | train loss: 0.011
# epoch: 3 | train loss: 0.013
# epoch: 4 | train loss: 0.012
# epoch: 5 | train loss: 0.014
# epoch: 6 | train loss: 0.013
# epoch: 7 | train loss: 0.011
# epoch: 8 | train loss: 0.012
# epoch: 9 | train loss: 0.012
# epoch: 10 | train loss: 0.012
# epoch: 11 | train loss: 0.013
# epoch: 12 | train loss: 0.012
# epoch: 13 | train loss: 0.013
# epoch: 14 | train loss: 0.012
# epoch: 15 | train loss: 0.011
# epoch: 16 | train loss: 0.011
# epoch: 17 | train loss: 0.011
# epoch: 18 | train loss: 0.011
# epoch: 19 | train loss: 0.013
# epoch: 20 | train loss: 0.012
# epoch: 21 | train loss: 0.011
# epoch: 22 | train loss: 0.012
# epoch: 23 | train loss: 0.011
# epoch: 24 | train loss: 0.011
# epoch: 25 | train loss: 0.010
# epoch: 26 | train loss: 0.011
# epoch: 27 | train loss: 0.011
# epoch: 28 | train loss: 0.011
# epoch: 29 | train loss: 0.009
# epoch: 30 | train loss: 0.012
# epoch: 31 | train loss: 0.011
# epoch: 32 | train loss: 0.012
# epoch: 33 | train loss: 0.011
# epoch: 34 | train loss: 0.011
# epoch: 35 | train loss: 0.012
# epoch: 36 | train loss: 0.011
# epoch: 37 | train loss: 0.010
# epoch: 38 | train loss: 0.010
# epoch: 39 | train loss: 0.011
# epoch: 40 | train loss: 0.011
# epoch: 41 | train loss: 0.012
# epoch: 42 | train loss: 0.011
# epoch: 43 | train loss: 0.012
# epoch: 44 | train loss: 0.009
# epoch: 45 | train loss: 0.011
# epoch: 46 | train loss: 0.011
# epoch: 47 | train loss: 0.011
# epoch: 48 | train loss: 0.011
# epoch: 49 | train loss: 0.011
# epoch: 50 | train loss: 0.010
# epoch: 51 | train loss: 0.012
# epoch: 52 | train loss: 0.011
# epoch: 53 | train loss: 0.010
# epoch: 54 | train loss: 0.011
# epoch: 55 | train loss: 0.011
# epoch: 56 | train loss: 0.010
# epoch: 57 | train loss: 0.010
# epoch: 58 | train loss: 0.010
# epoch: 59 | train loss: 0.011
# epoch: 60 | train loss: 0.011
# epoch: 61 | train loss: 0.010
# epoch: 62 | train loss: 0.010
# epoch: 63 | train loss: 0.011
# epoch: 64 | train loss: 0.011
# epoch: 65 | train loss: 0.010
# epoch: 66 | train loss: 0.010
# epoch: 67 | train loss: 0.010
# epoch: 68 | train loss: 0.009
# epoch: 69 | train loss: 0.011
# epoch: 70 | train loss: 0.010
# epoch: 71 | train loss: 0.011
# epoch: 72 | train loss: 0.010
# epoch: 73 | train loss: 0.010
# epoch: 74 | train loss: 0.011
# epoch: 75 | train loss: 0.012
# epoch: 76 | train loss: 0.010
# epoch: 77 | train loss: 0.011
# epoch: 78 | train loss: 0.010
# epoch: 79 | train loss: 0.011
# epoch: 80 | train loss: 0.010
# epoch: 81 | train loss: 0.011
# epoch: 82 | train loss: 0.009
# epoch: 83 | train loss: 0.010
# epoch: 84 | train loss: 0.011
# epoch: 85 | train loss: 0.009
# epoch: 86 | train loss: 0.011
# epoch: 87 | train loss: 0.011
# epoch: 88 | train loss: 0.012
# epoch: 89 | train loss: 0.011
# epoch: 90 | train loss: 0.009
# epoch: 91 | train loss: 0.011
# epoch: 92 | train loss: 0.009
# epoch: 93 | train loss: 0.010
# epoch: 94 | train loss: 0.010
# epoch: 95 | train loss: 0.011
# epoch: 96 | train loss: 0.010
# epoch: 97 | train loss: 0.010
# epoch: 98 | train loss: 0.010
# epoch: 99 | train loss: 0.009
# epoch: 100 | train loss: 0.011
# epoch: 101 | train loss: 0.010
# epoch: 102 | train loss: 0.009
# epoch: 103 | train loss: 0.010
# epoch: 104 | train loss: 0.011
# epoch: 105 | train loss: 0.009
# epoch: 106 | train loss: 0.010
# epoch: 107 | train loss: 0.011
# epoch: 108 | train loss: 0.010
# epoch: 109 | train loss: 0.011
# epoch: 110 | train loss: 0.010
# epoch: 111 | train loss: 0.010
# epoch: 112 | train loss: 0.010
# epoch: 113 | train loss: 0.010
# epoch: 114 | train loss: 0.010
# epoch: 115 | train loss: 0.010
# epoch: 116 | train loss: 0.012
# epoch: 117 | train loss: 0.011
# epoch: 118 | train loss: 0.008
# epoch: 119 | train loss: 0.010
# epoch: 120 | train loss: 0.010
# epoch: 121 | train loss: 0.011
# epoch: 122 | train loss: 0.010
# epoch: 123 | train loss: 0.009
# epoch: 124 | train loss: 0.010
# epoch: 125 | train loss: 0.009
# epoch: 126 | train loss: 0.010
# epoch: 127 | train loss: 0.010
# epoch: 128 | train loss: 0.009
# epoch: 129 | train loss: 0.010
# epoch: 130 | train loss: 0.010
# epoch: 131 | train loss: 0.012
# epoch: 132 | train loss: 0.009
# epoch: 133 | train loss: 0.009
# epoch: 134 | train loss: 0.010
# epoch: 135 | train loss: 0.010
# epoch: 136 | train loss: 0.009
# epoch: 137 | train loss: 0.009
# epoch: 138 | train loss: 0.011
# epoch: 139 | train loss: 0.009
# epoch: 140 | train loss: 0.009
# epoch: 141 | train loss: 0.010
# epoch: 142 | train loss: 0.010
# epoch: 143 | train loss: 0.010
# epoch: 144 | train loss: 0.010
# epoch: 145 | train loss: 0.010
# epoch: 146 | train loss: 0.008
# epoch: 147 | train loss: 0.010
# epoch: 148 | train loss: 0.010
# epoch: 149 | train loss: 0.010
# epoch: 150 | train loss: 0.010
# epoch: 151 | train loss: 0.009
# epoch: 152 | train loss: 0.009
# epoch: 153 | train loss: 0.011
# epoch: 154 | train loss: 0.010
# epoch: 155 | train loss: 0.009
# epoch: 156 | train loss: 0.010
# epoch: 157 | train loss: 0.011
# epoch: 158 | train loss: 0.010
# epoch: 159 | train loss: 0.009
# epoch: 160 | train loss: 0.009
# epoch: 161 | train loss: 0.009
# epoch: 162 | train loss: 0.009
# epoch: 163 | train loss: 0.010
# epoch: 164 | train loss: 0.010
# epoch: 165 | train loss: 0.009
# epoch: 166 | train loss: 0.009
# epoch: 167 | train loss: 0.009
# epoch: 168 | train loss: 0.009
# epoch: 169 | train loss: 0.010
# epoch: 170 | train loss: 0.010
# epoch: 171 | train loss: 0.010
# epoch: 172 | train loss: 0.011
# epoch: 173 | train loss: 0.011
# epoch: 174 | train loss: 0.009
# epoch: 175 | train loss: 0.009
# epoch: 176 | train loss: 0.009
# epoch: 177 | train loss: 0.009
# epoch: 178 | train loss: 0.010
# epoch: 179 | train loss: 0.010
# epoch: 180 | train loss: 0.009
# epoch: 181 | train loss: 0.009
# epoch: 182 | train loss: 0.010
# epoch: 183 | train loss: 0.009
# epoch: 184 | train loss: 0.011
# epoch: 185 | train loss: 0.011
# epoch: 186 | train loss: 0.009
# epoch: 187 | train loss: 0.009
# epoch: 188 | train loss: 0.010
# epoch: 189 | train loss: 0.009
# epoch: 190 | train loss: 0.009
# epoch: 191 | train loss: 0.011
# epoch: 192 | train loss: 0.010
# epoch: 193 | train loss: 0.010
# epoch: 194 | train loss: 0.010
# epoch: 195 | train loss: 0.010
# epoch: 196 | train loss: 0.010
# epoch: 197 | train loss: 0.009
# epoch: 198 | train loss: 0.009
# epoch: 199 | train loss: 0.010
# epoch: 200 | train loss: 0.010
# epoch: 201 | train loss: 0.010
# epoch: 202 | train loss: 0.008
# epoch: 203 | train loss: 0.009
# epoch: 204 | train loss: 0.010
# epoch: 205 | train loss: 0.009
# epoch: 206 | train loss: 0.009
# epoch: 207 | train loss: 0.009
# epoch: 208 | train loss: 0.010
# epoch: 209 | train loss: 0.009
# epoch: 210 | train loss: 0.010
# epoch: 211 | train loss: 0.008
# epoch: 212 | train loss: 0.009
# epoch: 213 | train loss: 0.009
# epoch: 214 | train loss: 0.008
# epoch: 215 | train loss: 0.010
# epoch: 216 | train loss: 0.009
# epoch: 217 | train loss: 0.009
# epoch: 218 | train loss: 0.009
# epoch: 219 | train loss: 0.011
# epoch: 220 | train loss: 0.009
# epoch: 221 | train loss: 0.009
# epoch: 222 | train loss: 0.009
# epoch: 223 | train loss: 0.009
# epoch: 224 | train loss: 0.009
# epoch: 225 | train loss: 0.009
# epoch: 226 | train loss: 0.009
# epoch: 227 | train loss: 0.011
# epoch: 228 | train loss: 0.010
# epoch: 229 | train loss: 0.009
# epoch: 230 | train loss: 0.009
# epoch: 231 | train loss: 0.009
# epoch: 232 | train loss: 0.010
# epoch: 233 | train loss: 0.010
# epoch: 234 | train loss: 0.010
# epoch: 235 | train loss: 0.010
# epoch: 236 | train loss: 0.010
# epoch: 237 | train loss: 0.009
# epoch: 238 | train loss: 0.009
# epoch: 239 | train loss: 0.010
# epoch: 240 | train loss: 0.008
# epoch: 241 | train loss: 0.009
# epoch: 242 | train loss: 0.010
# epoch: 243 | train loss: 0.009
# epoch: 244 | train loss: 0.009
# epoch: 245 | train loss: 0.011
# epoch: 246 | train loss: 0.009
# epoch: 247 | train loss: 0.010
# epoch: 248 | train loss: 0.011
# epoch: 249 | train loss: 0.009

# %%
# *********************************************************************************
#                               Sampling
# *********************************************************************************
sampler = SteeredDiffusionSampler(diffusion,
                                  backbone,
                                  train_loader,
                                  prior,
                                  pred_type='x0', # must be the same as in DiffusionTrainer
                                  )


num_samp = 750

high_samples = sampler.sample_loop(num_samples=num_samp, batch_size=32, pressure=8 , temperature=1)
low_samples = sampler.sample_loop(num_samples=num_samp, batch_size=32, pressure=1 , temperature=1)
high_samples = high_samples.numpy()
low_samples = low_samples.numpy()

# %%
# high_samples = high_samples.numpy()
# low_samples = low_samples.numpy()

# %%
high_samples.shape
# Out:
# (736, 4, 16, 16)

# %%
high_gen_data = high_samples[:,:2,:,:].reshape(high_samples.shape[0],2,256)
low_gen_data = low_samples[:,:2,:,:].reshape(low_samples.shape[0],2,256)

# %%
# high_gen_data

# %%
lambda1 = low_gen_data.mean(axis=2)
lambda3 = high_gen_data.mean(axis=2)

plt.figure(figsize=(5,4.5))
plt.scatter(lambda1[:,0],lambda1[:,1])
plt.scatter(lambda3[:,0],lambda3[:,1])

# %%
# lambda1 = low_gen_data.mean(axis=2)
lambda3 = high_gen_data.mean(axis=2)

plt.figure(figsize=(5,4.5))
plt.scatter(lambda1[:,0],lambda1[:,1])
plt.scatter(lambda3[:,0],lambda3[:,1])

# %%
lambda1 = low_gen_data.mean(axis=2)
lambda3 = high_gen_data.mean(axis=2)

plt.figure(figsize=(5,4.5))
plt.scatter(lambda1[:,0],lambda1[:,1])
plt.scatter(lambda3[:,0],lambda3[:,1])

# %%
highP_reference= np.load('data/lambda13_af_p8.npy')
lowP_reference = np.load('data/lambda13_af_p1.npy')

lambda1_ref = lowP_reference.mean(axis=2)
lambda3_ref = highP_reference.mean(axis=2)

# %%
plt.plot(highP_reference[11,0,:])
plt.plot(highP_reference[-11,0,:])
plt.plot(tmp1[-17,0,:])

# %%
plt.hist(lambda1_ref[:,0],color='b')
plt.hist(lambda1_ref[:,1],color='skyblue')

plt.hist(lambda1[:,0],color='r')
plt.hist(lambda1[:,1],color='orange')
# Out:
# (array([ 12.,  45., 106., 183., 206., 115.,  56.,   9.,   2.,   2.]),
#  array([0.04005406, 0.04050138, 0.0409487 , 0.04139603, 0.04184335,
#         0.04229068, 0.042738  , 0.04318532, 0.04363265, 0.04407997,
#         0.0445273 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(lambda1_ref[:,0],color='b')
plt.hist(lambda1_ref[:,1],color='skyblue')

plt.hist(lambda1[:,0],color='r')
plt.hist(lambda1[:,1],color='orange')
# Out:
# (array([253.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 227.]),
#  array([-0.01244746,  0.02394689,  0.06034125,  0.0967356 ,  0.13312997,
#          0.16952431,  0.20591867,  0.24231303,  0.27870739,  0.31510174,
#          0.3514961 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(lambda1_ref[:,0])
plt.plot(lambda1[:,0])

plt.plot(lambda1_ref[:,1])
plt.plot(lambda1[:,1])

# %%
plt.plot(lambda3_ref[:,0])
plt.plot(lambda3[:,0])

plt.plot(lambda3_ref[:,1])
plt.plot(lambda3[:,1])

# %%
highP_reference.shape
# Out:
# (10000, 2, 256)

# %%
# lambda3_ref

highP_ref_img = highP_reference[:10,:,:]
highP_ref_img = highP_ref_img.reshape(10,2,16,16)

# %%
plt.figure(figsize=(10,8))
for i in range(10):
    plt.subplot(2,5,i+1)
    im = plt.imshow(highP_ref_img[-i,0,:,:], vmin=0, vmax=1)
    plt.colorbar(im)

# %%
# high_samples[:,0,:,:]

plt.figure(figsize=(10,8))
for i in range(10):
    plt.subplot(2,5,i+1)
    im = plt.imshow(high_samples[i,0,:,:], vmin=0, vmax=1)
    plt.colorbar(im)

# %%
high_samples = high_samples.numpy()
low_samples = low_samples.numpy()

x_p1 = np.concatenate(np.concatenate(low_samples[:,:2,:,:]))
x_p1 = np.concatenate(x_p1)
x_p12 = np.concatenate(np.concatenate(high_samples[:,:2,:,:]))
x_p12 = np.concatenate(x_p12)

plt.figure(figsize=(5,4.5))
sns.kdeplot(x_p1,label='Low P', fill=True)#, color="blue")
sns.kdeplot(x_p12,label='High P', fill=True)#, color="blue")
# plt.xlim([-50,150])
plt.legend()
plt.xlabel('angle (not scaled)')
plt.savefig('plots/distribution_t2.pdf')


# Temperature depedent 
temp=[1,2,3,4,5]
high_samp=[]
low_samp=[]

for i in temp: 
    locals()['high_samples_t_{0}'.format(i)] = sampler.sample_loop(num_samples=num_samp, batch_size=32, pressure=5 , temperature=i)
    locals()['low_samples_t_{0}'.format(i)] = sampler.sample_loop(num_samples=num_samp, batch_size=32, pressure=0 , temperature=i)

    high_samp.append(locals()['high_samples_t_{0}'.format(i)])
    low_samp.append(locals()['low_samples_t_{0}'.format(i)])
    
high_samp = np.array(high_samp)
low_samp = np.array(low_samp)
    
# high_samp = np.array([high_samples_t_1,high_samples_t_3,high_samples_t_5,high_samples_t_7,high_samples_t_10])
# low_samp = np.array([low_samples_t_1,low_samples_t_3,low_samples_t_5,low_samples_t_7,low_samples_t_10])

np.save('data/high_samp.npy',high_samp)
np.save('data/low_samp.npy',low_samp)

# Pressure dependent 
presL=[0,10,20]
presH=[30,40,50]

highP_samp = []
lowP_samp = []

for i ,p1 in enumerate(presL): 
    p12  =presH[i]
    
    locals()['high_samples_p_{0}'.format(i)] = sampler.sample_loop(num_samples=num_samp, batch_size=32, pressure=p12/10 , temperature=2)
    locals()['low_samples_p_{0}'.format(i)] = sampler.sample_loop(num_samples=num_samp, batch_size=32, pressure=p1/10 , temperature=2)
    highP_samp.append(locals()['high_samples_p_{0}'.format(i)])
    lowP_samp.append(locals()['low_samples_p_{0}'.format(i)])


highP= np.load('data/pressure_high.npy')
lowP = np.load('data/pressure_low.npy')

highP_denisty = highP[400::20, :, :, :12]/(180/np.pi)
highP_denisty = highP_denisty.transpose(0,3,1,2)
lowP_denisty = lowP[400::20, :, :, :12]/(180/np.pi)
lowP_denisty = lowP_denisty.transpose(0,3,1,2)



# highP_samp = np.array([high_samples_p_5,high_samples_p_10,high_samples_p_15,high_samples_p_20,])
# lowP_samp = np.array([low_samples_p_5,low_samples_p_10,low_samples_p_15,low_samples_p_20])

highP_samp = np.array(highP_samp)
lowP_samp = np.array(lowP_samp)


np.save('data/highP_samp.npy',highP_samp)
np.save('data/lowP_samp.npy',lowP_samp)


# Pressure dependent 
plt.figure(figsize=(10,4.5))
plt.subplot(1,2,1)
sns.kdeplot(convert_data_visual(highP_denisty),label='ref', fill=False, color="blue")
for i,sample in enumerate(highP_samp):
    sns.kdeplot(convert_data_visual(sample),label='P=%i'%(presH[i]/10), fill=True)#, color="blue")
plt.legend()
plt.xlim([-50,150])
plt.xlabel('angle (not scaled)')

plt.subplot(1,2,2)
sns.kdeplot(convert_data_visual(lowP_denisty),label='ref', fill=False, color="red")
for i,sample in enumerate(lowP_samp):
    sns.kdeplot(convert_data_visual(sample),label='P=%i'%(presL[i]/10), fill=True)#, color="blue")
plt.legend()
plt.xlabel('angle (not scaled)')
plt.xlim([-50,150])
plt.savefig('plots/pressure_dependent.pdf')

# Temperature dependent 
plt.figure(figsize=(10,4.5))
plt.subplot(1,2,1)
sns.kdeplot(convert_data_visual(highP_denisty),label='ref', fill=False, color="blue")
for i,sample in enumerate(high_samp):
    sns.kdeplot(convert_data_visual(sample),label=temp[i], fill=True)#, color="blue")
plt.legend()
plt.xlabel('angle (not scaled)')
plt.xlim([-50,150])

plt.subplot(1,2,2)
sns.kdeplot(convert_data_visual(lowP_denisty),label='ref', fill=False, color="red")
for i,sample in enumerate(low_samp):
    sns.kdeplot(convert_data_visual(sample),label=temp[i], fill=True)#, color="blue")
plt.legend()
plt.xlabel('angle (not scaled)')
plt.xlim([-50,150])
plt.savefig('plots/temperature_dependent.pdf')



high_samples = high_samples_t_5
low_samples = low_samples_t_5

plt.figure(figsize=(20,10))
for j in range(12):
    # for i in range(1):
    plt.subplot(4,6,j+1)
    plt.imshow(high_samples[8,j,:,:]*180/np.pi,vmin=0,vmax=90)
    if j==0:  plt.title('high P sample angles')
    plt.colorbar()

# plt.figure(figsize=(20,5))
for j in range(12):
    # for i in range(1):
    plt.subplot(4,6,j+13)
    plt.imshow(low_samples[8,j,:,:]*180/np.pi,vmin=0,vmax=90)
    if j==0: plt.title('low P sample angles')
    plt.colorbar()
plt.tight_layout() 
plt.savefig('plots/low_distribution.pdf')


# Temperature dependent 
plt.figure(figsize=(10,4.5))
plt.subplot(1,2,1)
sns.kdeplot(convert_data_visual(highP_denisty),label='ref', fill=False, color="blue")
sns.kdeplot(convert_data_visual(high_samples_t_5),label=temp[i], fill=True)#, color="blue")
plt.legend()
plt.xlabel('angle (not scaled)')

plt.subplot(1,2,2)
sns.kdeplot(convert_data_visual(lowP_denisty),label='ref', fill=False, color="red")
sns.kdeplot(convert_data_visual(low_samples_t_5),label=temp[i], fill=True)#, color="blue")
plt.legend()
plt.xlabel('angle (not scaled)')
plt.savefig('plots/temperature_5_dependent.pdf')

# %%
lambda1 = lowP_data.mean(axis=2)
lambda3 = highP_data.mean(axis=2)

plt.figure(figsize=(5,4.5))
plt.scatter(lambda1[:,0],lambda1[:,1])
plt.scatter(lambda3[:,0],lambda3[:,1])
# plt.xlim([0,1])
# plt.ylim([0,1])
